# %%
import pandas as pd
import warnings
warnings.filterwarnings('ignore')
data=pd.read_csv("/home/placement/Downloads/rainfall in india 1901-2015.csv")

# %%
data
# Out:
#                     SUBDIVISION  YEAR   JAN    FEB   MAR    APR    MAY    JUN  \
# 0     ANDAMAN & NICOBAR ISLANDS  1901  49.2   87.1  29.2    2.3  528.8  517.5
# 1     ANDAMAN & NICOBAR ISLANDS  1902   0.0  159.8  12.2    0.0  446.1  537.1
# 2     ANDAMAN & NICOBAR ISLANDS  1903  12.7  144.0   0.0    1.0  235.1  479.9
# 3     ANDAMAN & NICOBAR ISLANDS  1904   9.4   14.7   0.0  202.4  304.5  495.1
# 4     ANDAMAN & NICOBAR ISLANDS  1905   1.3    0.0   3.3   26.9  279.5  628.7
# ...                         ...   ...   ...    ...   ...    ...    ...    ...
# 4111                LAKSHADWEEP  2011   5.1    2.8   3.1   85.9  107.2  153.6
# 4112                LAKSHADWEEP  2012  19.2    0.1   1.6   76.8   21.2  327.0
# 4113                LAKSHADWEEP  2013  26.2   34.4  37.5    5.3   88.3  426.2
# 4114                LAKSHADWEEP  2014  53.2   16.1   4.4   14.9   57.4  244.1
# 4115                LAKSHADWEEP  2015   2.2    0.5   3.7   87.1  133.1  296.6
#
# ...

# %%
data.describe()
# Out:
#               YEAR          JAN          FEB          MAR          APR  \
# count  4116.000000  4112.000000  4113.000000  4110.000000  4112.000000
# mean   1958.218659    18.957320    21.805325    27.359197    43.127432
# std      33.140898    33.585371    35.909488    46.959424    67.831168
# min    1901.000000     0.000000     0.000000     0.000000     0.000000
# 25%    1930.000000     0.600000     0.600000     1.000000     3.000000
# 50%    1958.000000     6.000000     6.700000     7.800000    15.700000
# 75%    1987.000000    22.200000    26.800000    31.300000    49.950000
# max    2015.000000   583.700000   403.500000   605.600000   595.100000
#
#                MAY          JUN          JUL          AUG          SEP  \
# count  4113.000000  4111.000000  4109.000000  4112.000000  4110.000000
# mean     85.745417   230.234444   347.214334   290.263497   197.361922
# std     123.234904   234.710758   269.539667   188.770477   135.408345
# ...

# %% [markdown]
# # loc()

# %%
data1=data.loc[(data.SUBDIVISION=='COASTAL ANDHRA PRADESH')]

# %%
data1
# Out:
#                  SUBDIVISION  YEAR   JAN   FEB   MAR   APR    MAY    JUN  \
# 3082  COASTAL ANDHRA PRADESH  1901  18.8  80.9   7.2  28.7   68.7   77.7
# 3083  COASTAL ANDHRA PRADESH  1902   2.0   0.0   2.8  23.9   37.6   72.6
# 3084  COASTAL ANDHRA PRADESH  1903   0.8  13.3   0.2   6.2   73.4  154.0
# 3085  COASTAL ANDHRA PRADESH  1904   1.3   0.0   5.4   3.0  136.3  107.8
# 3086  COASTAL ANDHRA PRADESH  1905   1.1  16.7  68.0  37.0   68.8   84.4
# ...                      ...   ...   ...   ...   ...   ...    ...    ...
# 3192  COASTAL ANDHRA PRADESH  2011   0.0  17.9   0.9  62.3   67.9   86.8
# 3193  COASTAL ANDHRA PRADESH  2012  37.6   0.0   2.7  24.0   39.3   95.4
# 3194  COASTAL ANDHRA PRADESH  2013   2.0  29.6   0.2  48.0   28.2  127.5
# 3195  COASTAL ANDHRA PRADESH  2014   0.4   1.2   9.1   6.0  112.9   45.7
# 3196  COASTAL ANDHRA PRADESH  2015   2.0   0.6   5.5  32.3   34.1  283.8
#
#         JUL    AUG    SEP    OCT    NOV   DEC  ANNUAL  Jan-Feb  Mar-May  \
# ...

# %% [markdown]
# # groupby()

# %%
data2=data.groupby(['SUBDIVISION']).count()

# %%
data2
# Out:
#                                     YEAR  JAN  FEB  MAR  APR  MAY  JUN  JUL  \
# SUBDIVISION
# ANDAMAN & NICOBAR ISLANDS            110  110  110  108  108  109  108  108
# ARUNACHAL PRADESH                     97   96   96   95   97   97   96   96
# ASSAM & MEGHALAYA                    115  115  115  115  115  115  115  115
# BIHAR                                115  115  115  115  115  115  115  115
# CHHATTISGARH                         115  115  115  115  115  115  115  115
# COASTAL ANDHRA PRADESH               115  115  115  115  115  115  115  115
# COASTAL KARNATAKA                    115  114  115  115  115  115  115  115
# EAST MADHYA PRADESH                  115  115  115  115  115  115  115  115
# EAST RAJASTHAN                       115  115  115  115  115  115  115  115
# EAST UTTAR PRADESH                   115  115  115  115  115  115  115  115
# GANGETIC WEST BENGAL                 115  115  115  115  115  115  115  115
# ...

# %%
data['SUBDIVISION'].count()
# Out:
# 4116

# %%
data.isna().sum()
# Out:
# SUBDIVISION     0
# YEAR            0
# JAN             4
# FEB             3
# MAR             6
# APR             4
# MAY             3
# JUN             5
# JUL             7
# AUG             4
# SEP             6
# OCT             7
# NOV            11
# DEC            10
# ANNUAL         26
# Jan-Feb         6
# Mar-May         9
# Jun-Sep        10
# Oct-Dec        13
# dtype: int64

# %%
data3=data.loc[(data.YEAR<=2015)]

# %%
data3.tail(10)
# Out:
#       SUBDIVISION  YEAR   JAN   FEB    MAR   APR    MAY    JUN    JUL    AUG  \
# 4106  LAKSHADWEEP  2006  20.1   0.0   33.0   0.3  327.9  286.9  172.3  150.7
# 4107  LAKSHADWEEP  2007   2.5   4.2    0.2  22.2  166.2  573.4  427.4  294.7
# 4108  LAKSHADWEEP  2008   5.5  19.8  120.7  15.8  180.4  254.6  363.9  206.6
# 4109  LAKSHADWEEP  2009   4.7   1.5    0.1  18.1  162.1  401.2  266.4  185.0
# 4110  LAKSHADWEEP  2010  18.8   0.0    1.2  35.6   79.0  318.9  336.7  335.1
# 4111  LAKSHADWEEP  2011   5.1   2.8    3.1  85.9  107.2  153.6  350.2  254.0
# 4112  LAKSHADWEEP  2012  19.2   0.1    1.6  76.8   21.2  327.0  231.5  381.2
# 4113  LAKSHADWEEP  2013  26.2  34.4   37.5   5.3   88.3  426.2  296.4  154.4
# 4114  LAKSHADWEEP  2014  53.2  16.1    4.4  14.9   57.4  244.1  116.1  466.1
# 4115  LAKSHADWEEP  2015   2.2   0.5    3.7  87.1  133.1  296.6  257.5  146.4
#
#         SEP    OCT    NOV    DEC  ANNUAL  Jan-Feb  Mar-May  Jun-Sep  Oct-Dec
# ...

# %%
data4=data3.drop(columns=["ANNUAL","Jan-Feb","Mar-May","Jun-Sep","Oct-Dec"])

# %%
data4
# Out:
#                     SUBDIVISION  YEAR   JAN    FEB   MAR    APR    MAY    JUN  \
# 0     ANDAMAN & NICOBAR ISLANDS  1901  49.2   87.1  29.2    2.3  528.8  517.5
# 1     ANDAMAN & NICOBAR ISLANDS  1902   0.0  159.8  12.2    0.0  446.1  537.1
# 2     ANDAMAN & NICOBAR ISLANDS  1903  12.7  144.0   0.0    1.0  235.1  479.9
# 3     ANDAMAN & NICOBAR ISLANDS  1904   9.4   14.7   0.0  202.4  304.5  495.1
# 4     ANDAMAN & NICOBAR ISLANDS  1905   1.3    0.0   3.3   26.9  279.5  628.7
# ...                         ...   ...   ...    ...   ...    ...    ...    ...
# 4111                LAKSHADWEEP  2011   5.1    2.8   3.1   85.9  107.2  153.6
# 4112                LAKSHADWEEP  2012  19.2    0.1   1.6   76.8   21.2  327.0
# 4113                LAKSHADWEEP  2013  26.2   34.4  37.5    5.3   88.3  426.2
# 4114                LAKSHADWEEP  2014  53.2   16.1   4.4   14.9   57.4  244.1
# 4115                LAKSHADWEEP  2015   2.2    0.5   3.7   87.1  133.1  296.6
#
# ...

# %%
data3.columns
# Out:
# Index(['SUBDIVISION', 'YEAR', 'JAN', 'FEB', 'MAR', 'APR', 'MAY', 'JUN', 'JUL',
#        'AUG', 'SEP', 'OCT', 'NOV', 'DEC', 'ANNUAL', 'Jan-Feb', 'Mar-May',
#        'Jun-Sep', 'Oct-Dec'],
#       dtype='object')

# %%
data["SUBDIVISION"].unique()
# Out:
# array(['ANDAMAN & NICOBAR ISLANDS', 'ARUNACHAL PRADESH',
#        'ASSAM & MEGHALAYA', 'NAGA MANI MIZO TRIPURA',
#        'SUB HIMALAYAN WEST BENGAL & SIKKIM', 'GANGETIC WEST BENGAL',
#        'ORISSA', 'JHARKHAND', 'BIHAR', 'EAST UTTAR PRADESH',
#        'WEST UTTAR PRADESH', 'UTTARAKHAND', 'HARYANA DELHI & CHANDIGARH',
#        'PUNJAB', 'HIMACHAL PRADESH', 'JAMMU & KASHMIR', 'WEST RAJASTHAN',
#        'EAST RAJASTHAN', 'WEST MADHYA PRADESH', 'EAST MADHYA PRADESH',
#        'GUJARAT REGION', 'SAURASHTRA & KUTCH', 'KONKAN & GOA',
#        'MADHYA MAHARASHTRA', 'MATATHWADA', 'VIDARBHA', 'CHHATTISGARH',
#        'COASTAL ANDHRA PRADESH', 'TELANGANA', 'RAYALSEEMA', 'TAMIL NADU',
#        'COASTAL KARNATAKA', 'NORTH INTERIOR KARNATAKA',
#        'SOUTH INTERIOR KARNATAKA', 'KERALA', 'LAKSHADWEEP'], dtype=object)

# %%
data5=data4.loc[(data.SUBDIVISION=='JAMMU & KASHMIR')]

# %%
data5
# Out:
#           SUBDIVISION  YEAR    JAN    FEB    MAR    APR    MAY    JUN    JUL  \
# 1702  JAMMU & KASHMIR  1901   66.4   69.3   69.6  132.2  105.8   53.4  171.7
# 1703  JAMMU & KASHMIR  1902    6.5    9.7   91.3  100.5   70.7  113.3  108.4
# 1704  JAMMU & KASHMIR  1903   96.2   21.5  238.6   58.7   57.3   18.9  332.5
# 1705  JAMMU & KASHMIR  1904  110.6   17.3  145.2   64.5   67.8   25.9  182.3
# 1706  JAMMU & KASHMIR  1905  146.7   76.3  161.4   71.7   65.2   43.3  145.2
# ...               ...   ...    ...    ...    ...    ...    ...    ...    ...
# 1812  JAMMU & KASHMIR  2011   43.4  211.6   97.8   89.0   32.4   72.5   81.6
# 1813  JAMMU & KASHMIR  2012  150.9   95.8   45.2   86.6   48.9   32.6  118.8
# 1814  JAMMU & KASHMIR  2013   52.2  136.4   41.9   47.4   47.4   80.5  125.1
# 1815  JAMMU & KASHMIR  2014   75.8   64.0  153.1   76.1   52.7   25.3  100.5
# 1816  JAMMU & KASHMIR  2015   27.9  187.2  341.4  173.3   64.6  121.4  233.2
#
#         AUG    SEP   OCT   NOV   DEC
# ...

# %%
data5.isna().sum()
# Out:
# SUBDIVISION    0
# YEAR           0
# JAN            0
# FEB            0
# MAR            0
# APR            0
# MAY            0
# JUN            0
# JUL            1
# AUG            0
# SEP            0
# OCT            0
# NOV            1
# DEC            1
# dtype: int64

# %%
data6=data5.fillna(data.mean())

# %%
data6.isna().sum()
# Out:
# SUBDIVISION    0
# YEAR           0
# JAN            0
# FEB            0
# MAR            0
# APR            0
# MAY            0
# JUN            0
# JUL            0
# AUG            0
# SEP            0
# OCT            0
# NOV            0
# DEC            0
# dtype: int64

# %%
data6
# Out:
#           SUBDIVISION  YEAR    JAN    FEB    MAR    APR    MAY    JUN    JUL  \
# 1702  JAMMU & KASHMIR  1901   66.4   69.3   69.6  132.2  105.8   53.4  171.7
# 1703  JAMMU & KASHMIR  1902    6.5    9.7   91.3  100.5   70.7  113.3  108.4
# 1704  JAMMU & KASHMIR  1903   96.2   21.5  238.6   58.7   57.3   18.9  332.5
# 1705  JAMMU & KASHMIR  1904  110.6   17.3  145.2   64.5   67.8   25.9  182.3
# 1706  JAMMU & KASHMIR  1905  146.7   76.3  161.4   71.7   65.2   43.3  145.2
# ...               ...   ...    ...    ...    ...    ...    ...    ...    ...
# 1812  JAMMU & KASHMIR  2011   43.4  211.6   97.8   89.0   32.4   72.5   81.6
# 1813  JAMMU & KASHMIR  2012  150.9   95.8   45.2   86.6   48.9   32.6  118.8
# 1814  JAMMU & KASHMIR  2013   52.2  136.4   41.9   47.4   47.4   80.5  125.1
# 1815  JAMMU & KASHMIR  2014   75.8   64.0  153.1   76.1   52.7   25.3  100.5
# 1816  JAMMU & KASHMIR  2015   27.9  187.2  341.4  173.3   64.6  121.4  233.2
#
#         AUG    SEP   OCT   NOV   DEC
# ...

# %% [markdown]
# # Adding columns using lambda function

# %%
data6["ANNUAL_RAIN"]=data6.apply(lambda R:R.JAN+R.FEB+R.MAR+R.APR+R.MAY+R.JUN+R.JUL+R.AUG+R.SEP+R.OCT+R.NOV+R.DEC,axis=1)

# %%
data6
# Out:
#           SUBDIVISION  YEAR    JAN    FEB    MAR    APR    MAY    JUN    JUL  \
# 1702  JAMMU & KASHMIR  1901   66.4   69.3   69.6  132.2  105.8   53.4  171.7
# 1703  JAMMU & KASHMIR  1902    6.5    9.7   91.3  100.5   70.7  113.3  108.4
# 1704  JAMMU & KASHMIR  1903   96.2   21.5  238.6   58.7   57.3   18.9  332.5
# 1705  JAMMU & KASHMIR  1904  110.6   17.3  145.2   64.5   67.8   25.9  182.3
# 1706  JAMMU & KASHMIR  1905  146.7   76.3  161.4   71.7   65.2   43.3  145.2
# ...               ...   ...    ...    ...    ...    ...    ...    ...    ...
# 1812  JAMMU & KASHMIR  2011   43.4  211.6   97.8   89.0   32.4   72.5   81.6
# 1813  JAMMU & KASHMIR  2012  150.9   95.8   45.2   86.6   48.9   32.6  118.8
# 1814  JAMMU & KASHMIR  2013   52.2  136.4   41.9   47.4   47.4   80.5  125.1
# 1815  JAMMU & KASHMIR  2014   75.8   64.0  153.1   76.1   52.7   25.3  100.5
# 1816  JAMMU & KASHMIR  2015   27.9  187.2  341.4  173.3   64.6  121.4  233.2
#
# ...

# %%
data6['total']=data6['JAN']+data6['FEB']+data6['MAR']+data6['APR']+data6['MAY']+data6['JUN']+data6['JUL']+data6['AUG']+data6['SEP']+data6['OCT']+data6['NOV']+data6['DEC']
data6
# Out:
#           SUBDIVISION  YEAR    JAN    FEB    MAR    APR    MAY    JUN    JUL  \
# 1702  JAMMU & KASHMIR  1901   66.4   69.3   69.6  132.2  105.8   53.4  171.7
# 1703  JAMMU & KASHMIR  1902    6.5    9.7   91.3  100.5   70.7  113.3  108.4
# 1704  JAMMU & KASHMIR  1903   96.2   21.5  238.6   58.7   57.3   18.9  332.5
# 1705  JAMMU & KASHMIR  1904  110.6   17.3  145.2   64.5   67.8   25.9  182.3
# 1706  JAMMU & KASHMIR  1905  146.7   76.3  161.4   71.7   65.2   43.3  145.2
# ...               ...   ...    ...    ...    ...    ...    ...    ...    ...
# 1812  JAMMU & KASHMIR  2011   43.4  211.6   97.8   89.0   32.4   72.5   81.6
# 1813  JAMMU & KASHMIR  2012  150.9   95.8   45.2   86.6   48.9   32.6  118.8
# 1814  JAMMU & KASHMIR  2013   52.2  136.4   41.9   47.4   47.4   80.5  125.1
# 1815  JAMMU & KASHMIR  2014   75.8   64.0  153.1   76.1   52.7   25.3  100.5
# 1816  JAMMU & KASHMIR  2015   27.9  187.2  341.4  173.3   64.6  121.4  233.2
#
# ...

# %%
data6
# Out:
#           SUBDIVISION  YEAR    JAN    FEB    MAR    APR    MAY    JUN    JUL  \
# 1702  JAMMU & KASHMIR  1901   66.4   69.3   69.6  132.2  105.8   53.4  171.7
# 1703  JAMMU & KASHMIR  1902    6.5    9.7   91.3  100.5   70.7  113.3  108.4
# 1704  JAMMU & KASHMIR  1903   96.2   21.5  238.6   58.7   57.3   18.9  332.5
# 1705  JAMMU & KASHMIR  1904  110.6   17.3  145.2   64.5   67.8   25.9  182.3
# 1706  JAMMU & KASHMIR  1905  146.7   76.3  161.4   71.7   65.2   43.3  145.2
# ...               ...   ...    ...    ...    ...    ...    ...    ...    ...
# 1812  JAMMU & KASHMIR  2011   43.4  211.6   97.8   89.0   32.4   72.5   81.6
# 1813  JAMMU & KASHMIR  2012  150.9   95.8   45.2   86.6   48.9   32.6  118.8
# 1814  JAMMU & KASHMIR  2013   52.2  136.4   41.9   47.4   47.4   80.5  125.1
# 1815  JAMMU & KASHMIR  2014   75.8   64.0  153.1   76.1   52.7   25.3  100.5
# 1816  JAMMU & KASHMIR  2015   27.9  187.2  341.4  173.3   64.6  121.4  233.2
#
# ...

# %%
data6=data6.drop(columns='total')

# %%
data6
# Out:
#           SUBDIVISION  YEAR    JAN    FEB    MAR    APR    MAY    JUN    JUL  \
# 1702  JAMMU & KASHMIR  1901   66.4   69.3   69.6  132.2  105.8   53.4  171.7
# 1703  JAMMU & KASHMIR  1902    6.5    9.7   91.3  100.5   70.7  113.3  108.4
# 1704  JAMMU & KASHMIR  1903   96.2   21.5  238.6   58.7   57.3   18.9  332.5
# 1705  JAMMU & KASHMIR  1904  110.6   17.3  145.2   64.5   67.8   25.9  182.3
# 1706  JAMMU & KASHMIR  1905  146.7   76.3  161.4   71.7   65.2   43.3  145.2
# ...               ...   ...    ...    ...    ...    ...    ...    ...    ...
# 1812  JAMMU & KASHMIR  2011   43.4  211.6   97.8   89.0   32.4   72.5   81.6
# 1813  JAMMU & KASHMIR  2012  150.9   95.8   45.2   86.6   48.9   32.6  118.8
# 1814  JAMMU & KASHMIR  2013   52.2  136.4   41.9   47.4   47.4   80.5  125.1
# 1815  JAMMU & KASHMIR  2014   75.8   64.0  153.1   76.1   52.7   25.3  100.5
# 1816  JAMMU & KASHMIR  2015   27.9  187.2  341.4  173.3   64.6  121.4  233.2
#
# ...

# %%
data7=data6.drop(columns='SUBDIVISION')

# %%
data7
# Out:
#       YEAR    JAN    FEB    MAR    APR    MAY    JUN    JUL    AUG    SEP  \
# 1702  1901   66.4   69.3   69.6  132.2  105.8   53.4  171.7  181.3  101.8
# 1703  1902    6.5    9.7   91.3  100.5   70.7  113.3  108.4  136.9   62.2
# 1704  1903   96.2   21.5  238.6   58.7   57.3   18.9  332.5  218.6  176.9
# 1705  1904  110.6   17.3  145.2   64.5   67.8   25.9  182.3  132.2   62.3
# 1706  1905  146.7   76.3  161.4   71.7   65.2   43.3  145.2  111.5  239.7
# ...    ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 1812  2011   43.4  211.6   97.8   89.0   32.4   72.5   81.6  131.2   72.0
# 1813  2012  150.9   95.8   45.2   86.6   48.9   32.6  118.8  264.9  106.7
# 1814  2013   52.2  136.4   41.9   47.4   47.4   80.5  125.1  219.1   41.2
# 1815  2014   75.8   64.0  153.1   76.1   52.7   25.3  100.5  134.6  362.8
# 1816  2015   27.9  187.2  341.4  173.3   64.6  121.4  233.2  129.2  130.2
#
#        OCT   NOV   DEC  ANNUAL_RAIN
# 1702  24.1   0.0   4.4        980.0
# ...

# %%
data7['SWM']=data7['JUN']+data7['JUL']+data7['AUG']+data7['SEP']
data7['NEM']=data7['OCT']+data7['NOV']+data7['DEC']

# %%
data7
# Out:
#       YEAR    JAN    FEB    MAR    APR    MAY    JUN    JUL    AUG    SEP  \
# 1702  1901   66.4   69.3   69.6  132.2  105.8   53.4  171.7  181.3  101.8
# 1703  1902    6.5    9.7   91.3  100.5   70.7  113.3  108.4  136.9   62.2
# 1704  1903   96.2   21.5  238.6   58.7   57.3   18.9  332.5  218.6  176.9
# 1705  1904  110.6   17.3  145.2   64.5   67.8   25.9  182.3  132.2   62.3
# 1706  1905  146.7   76.3  161.4   71.7   65.2   43.3  145.2  111.5  239.7
# ...    ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 1812  2011   43.4  211.6   97.8   89.0   32.4   72.5   81.6  131.2   72.0
# 1813  2012  150.9   95.8   45.2   86.6   48.9   32.6  118.8  264.9  106.7
# 1814  2013   52.2  136.4   41.9   47.4   47.4   80.5  125.1  219.1   41.2
# 1815  2014   75.8   64.0  153.1   76.1   52.7   25.3  100.5  134.6  362.8
# 1816  2015   27.9  187.2  341.4  173.3   64.6  121.4  233.2  129.2  130.2
#
#        OCT   NOV   DEC  ANNUAL_RAIN    SWM    NEM
# ...

# %%
data8=data7.drop(columns=['JAN','FEB','MAR','APR','MAY','JUN','JUL','AUG','SEP','OCT','NOV','DEC'])

# %%
data8
# Out:
#       YEAR  ANNUAL_RAIN    SWM    NEM
# 1702  1901        980.0  508.2   28.5
# 1703  1902        760.4  420.8   60.9
# 1704  1903       1286.7  746.9   67.5
# 1705  1904        982.1  402.7  174.0
# 1706  1905       1157.6  539.7   96.6
# ...    ...          ...    ...    ...
# 1812  2011        887.6  357.3   56.1
# 1813  2012       1034.7  523.0   84.3
# 1814  2013        859.3  465.9   68.1
# 1815  2014       1093.5  623.2   48.6
# 1816  2015       1572.9  614.0  164.5
#
# [115 rows x 4 columns]

# %%
cor=data8.corr()

# %%
cor
# Out:
#                  YEAR  ANNUAL_RAIN       SWM       NEM
# YEAR         1.000000     0.199310  0.096365  0.081159
# ANNUAL_RAIN  0.199310     1.000000  0.725153  0.420021
# SWM          0.096365     0.725153  1.000000  0.151091
# NEM          0.081159     0.420021  0.151091  1.000000

# %%
import seaborn as sns
sns.heatmap(cor,vmax=1,vmin=-1,annot=True,linewidth=5,cmap='bwr')
# Out:
# <Axes: >
