# %%
import pandas as pd
data=pd.read_csv("/home/placement/Downloads/arunachal.csv")
data
# Out:
#     Unnamed: 0        SUBDIVISION  YEAR   JAN    FEB    MAR    APR    MAY  \
# 0          110  ARUNACHAL PRADESH  1916  48.1   69.8   71.1  316.1  424.6
# 1          111  ARUNACHAL PRADESH  1917  21.4  164.5    NaN  269.6  107.9
# 2          112  ARUNACHAL PRADESH  1918  10.4   11.0  191.2  144.6  861.1
# 3          113  ARUNACHAL PRADESH  1919  34.5   67.8   28.5  256.9  420.6
# 4          114  ARUNACHAL PRADESH  1920  14.0  196.3  605.6  364.7  173.6
# ..         ...                ...   ...   ...    ...    ...    ...    ...
# 86         196  ARUNACHAL PRADESH  2005  48.4  167.6  229.5  195.3  179.8
# 87         197  ARUNACHAL PRADESH  2006   6.0  103.7   63.3  202.7  321.7
# 88         198  ARUNACHAL PRADESH  2007  13.4   97.4   48.1  292.4  250.4
# 89         199  ARUNACHAL PRADESH  2008  76.7   39.7  122.6  192.4  185.0
# 90         200  ARUNACHAL PRADESH  2009  18.0   92.8   72.1  132.7  189.9
#
#        JUN     JUL    AUG    SEP    OCT   NOV   DEC  ANNUAL  Jan-Feb  Mar-May  \
# ...

# %%
data.shape
# Out:
# (91, 20)

# %%
data.columns
# Out:
# Index(['Unnamed: 0', 'SUBDIVISION', 'YEAR', 'JAN', 'FEB', 'MAR', 'APR', 'MAY',
#        'JUN', 'JUL', 'AUG', 'SEP', 'OCT', 'NOV', 'DEC', 'ANNUAL', 'Jan-Feb',
#        'Mar-May', 'Jun-Sep', 'Oct-Dec'],
#       dtype='object')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 91 entries, 0 to 90
# Data columns (total 20 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Unnamed: 0   91 non-null     int64
#  1   SUBDIVISION  91 non-null     object
#  2   YEAR         91 non-null     int64
#  3   JAN          90 non-null     float64
#  4   FEB          90 non-null     float64
#  5   MAR          89 non-null     float64
#  6   APR          91 non-null     float64
#  7   MAY          91 non-null     float64
#  8   JUN          90 non-null     float64
#  9   JUL          90 non-null     float64
#  10  AUG          91 non-null     float64
#  11  SEP          91 non-null     float64
#  12  OCT          89 non-null     float64
#  13  NOV          89 non-null     float64
#  14  DEC          89 non-null     float64
#  15  ANNUAL       85 non-null     float64
#  16  Jan-Feb      90 non-null     float64
#  17  Mar-May      89 non-null     float64
# ...

# %%
data.describe()
# Out:
#        Unnamed: 0         YEAR         JAN         FEB         MAR  \
# count    91.00000    91.000000   90.000000   90.000000   89.000000
# mean    155.00000  1962.747253   48.598889   93.966667  154.446067
# std      26.41338    27.695003   34.687078   46.258375   87.918484
# min     110.00000  1916.000000    1.800000    6.100000   28.500000
# 25%     132.50000  1938.500000   20.075000   65.625000  101.700000
# 50%     155.00000  1964.000000   45.400000   87.600000  141.700000
# 75%     177.50000  1986.500000   65.150000  120.400000  189.600000
# max     200.00000  2009.000000  164.500000  208.500000  605.600000
#
#               APR          MAY          JUN          JUL          AUG  \
# count   91.000000    91.000000    90.000000    90.000000    91.000000
# mean   262.990110   364.651648   659.556667   711.963333   502.163736
# std    113.395773   181.095447   311.642230   356.372598   275.716730
# min     94.700000   101.800000   239.400000   233.000000   172.400000
# ...

# %% [markdown]
# # drop()

# %%
data1=data.drop(columns='Unnamed: 0')

# %%
data1
# Out:
#           SUBDIVISION  YEAR   JAN    FEB    MAR    APR    MAY     JUN     JUL  \
# 0   ARUNACHAL PRADESH  1916  48.1   69.8   71.1  316.1  424.6  1124.9     NaN
# 1   ARUNACHAL PRADESH  1917  21.4  164.5    NaN  269.6  107.9   823.8   909.1
# 2   ARUNACHAL PRADESH  1918  10.4   11.0  191.2  144.6  861.1  1609.9  1303.0
# 3   ARUNACHAL PRADESH  1919  34.5   67.8   28.5  256.9  420.6   973.6   999.0
# 4   ARUNACHAL PRADESH  1920  14.0  196.3  605.6  364.7  173.6   840.6   535.4
# ..                ...   ...   ...    ...    ...    ...    ...     ...     ...
# 86  ARUNACHAL PRADESH  2005  48.4  167.6  229.5  195.3  179.8   269.3   430.8
# 87  ARUNACHAL PRADESH  2006   6.0  103.7   63.3  202.7  321.7   520.4   382.2
# 88  ARUNACHAL PRADESH  2007  13.4   97.4   48.1  292.4  250.4   530.2   761.0
# 89  ARUNACHAL PRADESH  2008  76.7   39.7  122.6  192.4  185.0   423.6   456.1
# 90  ARUNACHAL PRADESH  2009  18.0   92.8   72.1  132.7  189.9   259.1   329.9
#
# ...

# %% [markdown]
# # map()

# %%
data['SUBDIVISION']=data['SUBDIVISION'].map({'ARUNACHAL PRADESH':1})

# %%
data
# Out:
#     Unnamed: 0  SUBDIVISION  YEAR   JAN    FEB    MAR    APR    MAY     JUN  \
# 0          110            1  1916  48.1   69.8   71.1  316.1  424.6  1124.9
# 1          111            1  1917  21.4  164.5    NaN  269.6  107.9   823.8
# 2          112            1  1918  10.4   11.0  191.2  144.6  861.1  1609.9
# 3          113            1  1919  34.5   67.8   28.5  256.9  420.6   973.6
# 4          114            1  1920  14.0  196.3  605.6  364.7  173.6   840.6
# ..         ...          ...   ...   ...    ...    ...    ...    ...     ...
# 86         196            1  2005  48.4  167.6  229.5  195.3  179.8   269.3
# 87         197            1  2006   6.0  103.7   63.3  202.7  321.7   520.4
# 88         198            1  2007  13.4   97.4   48.1  292.4  250.4   530.2
# 89         199            1  2008  76.7   39.7  122.6  192.4  185.0   423.6
# 90         200            1  2009  18.0   92.8   72.1  132.7  189.9   259.1
#
# ...

# %% [markdown]
# # isna()

# %%
data1.isna().sum()
# Out:
# SUBDIVISION    0
# YEAR           0
# JAN            1
# FEB            1
# MAR            2
# APR            0
# MAY            0
# JUN            1
# JUL            1
# AUG            0
# SEP            0
# OCT            2
# NOV            2
# DEC            2
# ANNUAL         6
# Jan-Feb        1
# Mar-May        2
# Jun-Sep        2
# Oct-Dec        3
# dtype: int64

# %% [markdown]
# # fillna()

# %%
data2=data1.fillna(data.mean())

# %%
data2.isna().sum()
# Out:
# SUBDIVISION    0
# YEAR           0
# JAN            0
# FEB            0
# MAR            0
# APR            0
# MAY            0
# JUN            0
# JUL            0
# AUG            0
# SEP            0
# OCT            0
# NOV            0
# DEC            0
# ANNUAL         0
# Jan-Feb        0
# Mar-May        0
# Jun-Sep        0
# Oct-Dec        0
# dtype: int64

# %%
data2
# Out:
#           SUBDIVISION  YEAR   JAN    FEB         MAR    APR    MAY     JUN  \
# 0   ARUNACHAL PRADESH  1916  48.1   69.8   71.100000  316.1  424.6  1124.9
# 1   ARUNACHAL PRADESH  1917  21.4  164.5  154.446067  269.6  107.9   823.8
# 2   ARUNACHAL PRADESH  1918  10.4   11.0  191.200000  144.6  861.1  1609.9
# 3   ARUNACHAL PRADESH  1919  34.5   67.8   28.500000  256.9  420.6   973.6
# 4   ARUNACHAL PRADESH  1920  14.0  196.3  605.600000  364.7  173.6   840.6
# ..                ...   ...   ...    ...         ...    ...    ...     ...
# 86  ARUNACHAL PRADESH  2005  48.4  167.6  229.500000  195.3  179.8   269.3
# 87  ARUNACHAL PRADESH  2006   6.0  103.7   63.300000  202.7  321.7   520.4
# 88  ARUNACHAL PRADESH  2007  13.4   97.4   48.100000  292.4  250.4   530.2
# 89  ARUNACHAL PRADESH  2008  76.7   39.7  122.600000  192.4  185.0   423.6
# 90  ARUNACHAL PRADESH  2009  18.0   92.8   72.100000  132.7  189.9   259.1
#
# ...

# %%
# Out:
#        Unnamed: 0  SUBDIVISION         YEAR         JAN         FEB  \
# count    91.00000         91.0    91.000000   90.000000   90.000000
# mean    155.00000          1.0  1962.747253   48.598889   93.966667
# std      26.41338          0.0    27.695003   34.687078   46.258375
# min     110.00000          1.0  1916.000000    1.800000    6.100000
# 25%     132.50000          1.0  1938.500000   20.075000   65.625000
# 50%     155.00000          1.0  1964.000000   45.400000   87.600000
# 75%     177.50000          1.0  1986.500000   65.150000  120.400000
# max     200.00000          1.0  2009.000000  164.500000  208.500000
#
#               MAR         APR          MAY          JUN          JUL  \
# count   89.000000   91.000000    91.000000    90.000000    90.000000
# mean   154.446067  262.990110   364.651648   659.556667   711.963333
# std     87.918484  113.395773   181.095447   311.642230   356.372598
# min     28.500000   94.700000   101.800000   239.400000   233.000000
# ...
